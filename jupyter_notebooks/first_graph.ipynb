# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# !ls
# Out:
# first_graph.ipynb  processing_4g.txt  sample_result_4g.txt

# %%
data_total = []
data_processing = []

# %%
with open('sample_result_4g.txt', 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        data_total.append(int(line))

# %%
with open('processing_4g.txt', 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        data_processing.append(int(line))

# %%
data_total = np.array(data_total)
data_processing = np.array(data_processing)

# %%
f = plt.figure(figsize=(8, 4))
plt.ylim(0, 4700)
plt.grid()
plt.ylabel("Round-trip latency [ms]", fontsize=12)
plt.plot(data / 1e6)
plt.plot(data_processing / 1e6)

# %%
np.percentile(data, 50) / 1e9
# Out:
# 0.228034319

# %%
f = plt.figure(figsize=(8, 4))

plt.ecdf(data / 1e6)
plt.grid()
plt.xlim(0)
plt.ylim(0)

plt.xlabel("Round-trip latency [ms]")

plt.show()
